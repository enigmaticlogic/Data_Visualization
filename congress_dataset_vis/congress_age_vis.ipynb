# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

congress_df = pd.read_csv('congress-terms.csv')
congress_age = list(congress_df.age.values)

# plt.hist(congress_age, bins = 30)
# plt.ylabel('Frequency of Age')
# plt.xlabel('Age')
# plt.title('Ages of Congresspeople and Senators When First Elected')
# plt.savefig('congress_histogram.PNG')
# plt.show()

# plt.boxplot(congress_age)
# plt.title('Ages of Congresspeople and Senators When First Elected')
# plt.savefig('congress_boxplot.PNG')
# plt.show()

age_count = [congress_age.count(x) for x in congress_age]
plt.scatter(congress_age, age_count)
plt.ylabel('Frequency of Age')
plt.xlabel('Age')
plt.title('Ages of Congresspeople and Senators When First Elected')
plt.show()
