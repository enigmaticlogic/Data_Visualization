# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

congress_df = pd.read_csv('congress-terms.csv')
congress_age = list(congress_df.age.values)
congress_number = list(congress_df.congress.values)

plt.xkcd()
csfont = {'fontname': 'Comic Sans MS'}
plt.hist2d(congress_number, congress_age)
plt.ylabel('Age', color='b', **csfont)
plt.xlabel('Congress Number', color='r', **csfont)
plt.title('Ages of Congresspeople and Senators Across Congresses', color='xkcd:sky blue', **csfont)

ax = plt.gca()
ax.set_xlim(50,150)
ax.set_ylim(0,100)
ax.set_xticks(range(100))
ax.set_yticks(range(100))

badfontdict = {'fontsize': rcParams['axes.titlesize'], \
 'fontweight': rcParams['axes.titleweight'], \
 'verticalalignment': 'baseline', \
 'horizontalalignment': loc}

ax.set_xticklabels(fontdict=badfontdict)
plt.savefig('badvis.png')
plt.show()
